# %%
#Question 1

import numpy as np
x=np.random.rand(10,1)
print("Formed Matrix Is \n",x)

print("Mean Of The Above Matrix Is =",np.sum(x)/len(x))


#Second Method
print("Mean Of The Above Matrix Is =",np.mean(x))
# Out:
# Formed Matrix Is
#  [[0.37241407]
#  [0.59029328]
#  [0.64831771]
#  [0.11046474]
#  [0.42935075]
#  [0.8870795 ]
#  [0.79518368]
#  [0.07208599]
#  [0.08029116]
#  [0.27993096]]
# Mean Of The Above Matrix Is = 0.4265411845006476
# Mean Of The Above Matrix Is = 0.4265411845006476

# %%
#Question 2

x=np.random.rand(20,1)
print("Formed Matrix Is \n",x)

print("Variance of the formed matrix is =",np.var(x))


print("Standard deviation of the formed matrix is =",np.std(x))
#Second Method For standard deviation
print("Variance of the formed matrix is =",np.sqrt(np.var(x)))
# Out:
# Formed Matrix Is
#  [[0.1409732 ]
#  [0.84186587]
#  [0.85906325]
#  [0.41658577]
#  [0.55850218]
#  [0.09645293]
#  [0.08715437]
#  [0.56882939]
#  [0.14197133]
#  [0.98238417]
#  [0.2305642 ]
#  [0.82243769]
#  [0.27892079]
#  [0.20084056]
#  [0.82335289]
#  [0.26691669]
#  [0.79109434]
#  [0.05456388]
#  [0.67632445]
#  [0.59525798]]
# Variance of the formed matrix is = 0.09325528285191242
# Standard deviation of the formed matrix is = 0.30537727952798394
# Variance of the formed matrix is = 0.30537727952798394

# %%
#Question 3

A=np.random.rand(10,20)
B=np.random.rand(20,25)

x=np.dot(A,B)
print("Matrix Formed After Multiplication\n",x)


print("Sum Of Newly Formed Matrix = ",np.sum(x))
# Out:
# Matrix Formed After Multiplication
#  [[6.72651227 4.84913827 4.58116487 4.38459616 5.75823312 3.54372222
#   4.16093958 5.13740415 4.35080272 3.35452359 5.46211282 5.75166862
#   4.70493583 5.85646727 4.335563   3.93610602 4.84341805 5.78188585
#   4.64422661 4.43921183 5.05663346 4.79358711 5.89442712 4.31401835
#   6.09664053]
#  [6.7705851  5.42333731 5.67169236 4.82975075 6.5340101  4.46942411
#   4.86857922 6.13381888 5.0784848  4.01846264 6.6180269  6.10159214
#   5.85995022 6.7446588  4.76323243 5.0927509  5.2515221  6.22357254
#   6.4527293  4.69093364 4.76673466 4.96257931 6.60683306 5.94410369
#   6.17389851]
#  [7.51985385 5.15130918 6.86850381 5.71478906 7.7745985  4.99192893
#   6.50609637 7.44617206 5.41161757 4.65242371 6.90315916 6.22099371
#   5.40783395 7.26929239 5.7156369  6.20819442 6.53759125 7.83328543
#   6.26388248 5.61299116 6.0777635  6.05778602 7.11983107 6.16249999
#   7.93026986]
#  [5.19510849 3.4239325  4.5113995  3.65965133 4.59470644 3.45380216
#   3.8557756  4.03320243 3.6924047  3.21928375 4.33198272 4.901102
#   4.45929033 4.34443695 3.29015437 3.73311108 3.48707281 4.87146576
#   4.53213589 4.12880385 4.64076029 3.6351275  4.63619916 3.94614727
#   5.09639861]
#  [7.04499132 4.6581137  6.10872323 4.59459286 6.45393869 5.06295136
#   5.7356918  6.27003408 4.78578846 4.23583798 6.00719211 5.96222469
#   4.58425489 6.74152247 5.02291845 4.99589428 5.59804921 7.00061083
#   5.61848785 4.71308548 6.16673929 6.19766554 6.78839583 5.97804285
#   6.92600162]
#  [8.49634046 6.29535109 6.50048888 5.56499396 8.16064384 5.16918234
#   5.80863391 7.64806809 5.79031181 4.82748131 7.79437024 6.46025875
#   5.53488974 7.90035916 5.80428756 6.24596344 6.67973469 8.19953532
#   6.53595078 5.17215673 5.849091   6.2289205  7.7508789  6.86654987
#   7.85430506]
#  [6.15333594 4.89218385 4.38929652 3.5843437  4.75678336 3.52288214
#   3.14690914 4.98561014 4.34937955 3.25564182 5.64947198 4.82875254
#   3.82343291 5.46784575 4.26292717 3.6428428  4.5990825  4.67601678
#   5.29129329 2.95992501 3.90077889 3.93557867 5.65919071 4.6048837
#   4.75981872]
#  [5.90694878 5.09807859 4.79154807 3.96425753 5.8062932  3.76216032
#   3.67022056 5.37344517 4.29475069 3.2700812  5.50266986 5.37345803
#   4.45680392 5.58014059 4.74002905 4.28279932 4.36924791 5.08220467
#   5.37787911 3.37060105 3.88313616 4.39250956 6.09864776 5.3899591
#   5.19131824]
#  [4.11822238 3.1922704  3.40865581 2.95402329 4.08369378 2.78574484
#   2.86716998 3.44405818 3.52818408 2.27743293 3.37988216 3.75754891
#   3.4967906  3.57965116 2.84926416 2.40266756 2.73332502 3.93740609
#   3.46218778 2.76595367 3.47680493 3.70258557 4.35087743 3.53005057
#   3.86825894]
#  [7.61453925 5.86303733 6.19810891 5.49933424 7.09062525 5.23082632
#   5.93490709 6.43639171 5.42824724 4.29735069 6.92450271 6.30391902
#   5.67905113 6.90598883 5.00316273 5.61156824 5.88354242 7.53516434
#   6.83844029 5.39553301 6.16896143 5.87242479 6.80701736 6.54125304
#   7.47830137]]
# Sum Of Newly Formed Matrix =  1302.853764083786

# %%
#Question 4
#f(x)=1 / (1 + exp(-x)) 
from math import exp
y=np.random.rand(10,1)
print(y)
l=[]
for i in y:
    l.append(1/(1+exp(-(i))))
    
print("\n\n\nAfter performing given function")
print(np.array(l).reshape(10,1))
# Out:
# [[0.92065213]
#  [0.41306738]
#  [0.20974384]
#  [0.35570468]
#  [0.88816119]
#  [0.64611894]
#  [0.62900412]
#  [0.37754222]
#  [0.93865497]
#  [0.86094524]]
#
#
#
# After performing given function
# [[0.71517496]
#  [0.60182315]
#  [0.55224457]
#  [0.58800026]
#  [0.70851056]
#  [0.65613534]
#  [0.65226362]
#  [0.59328018]
#  [0.71882789]
#  [0.7028581 ]]
